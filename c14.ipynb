# %%
from c14.Detector import Detector
from c14.Emitter import Emitter

# %%
f = 0.1
k = 15
detectors = []
for r in [100, 250, 400]:
    detector = Detector(r, f)
    detector.update(k)
    detectors.append(detector)

first, *others = detectors
first.plot_with(others)

# %%
rs = range(1, 500, 1)

# %%
emitter = Emitter(rs)

# %%
emitter.update(15)

# %%
pmf_n = emitter.dist_of_n("n")
pmf_r = emitter.dist_of_r("r")

# %%
pmf_n.plot_with([pmf_r])
